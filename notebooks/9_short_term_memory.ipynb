# %% [markdown]
# # Short-Term Memory

# %%
from agents import Agent, Runner, SQLiteSession, trace
from setup import bedrock_tool
# Out:
# ✅ AWS credentials found
# ✅ OpenAI credentials found
# ✅ EXA credentials found

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
    model="litellm/bedrock/eu.amazon.nova-lite-v1:0",
)

# %% [markdown]
# ## No Memory

# %%
with trace("Compare without Memory") as t:
    result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: Let's compare the healthiness of bananas and lollipops:
#
# 1. **Bananas: 9/10 - Very healthy**
#    - High in essential nutrients such as potassium, vitamin B6, and vitamin C.
#    - Contains dietary fiber which aids in digestion.
#    - Provides natural sugars and energy.
#    - Low in fat and sodium.
#
# 2. **Lollipop: 1/10 - Unhealthy**
#    - High in sugar with little to no nutritional value.
#    - Can contribute to tooth decay and weight gain.
#    - Often contains artificial colors and flavors.
#    - Provides empty calories with no essential nutrients.
#
# So, bananas are significantly healthier than lollipops.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_36290149b6f74d57b86d8fb2b726639c

# %%
with trace("Add Apple - without Memory") as t:
    result = await Runner.run(nutrition_agent, "Add apples to the comparison")

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: Sure, let's compare apples to a few other foods and rate their healthiness from 1 to 10. Here's the list in order from the healthiest to the least healthy:
#
# 1) **Apples: 9/10**
#    - High in fiber, vitamins (especially vitamin C), and antioxidants. They are also low in calories and can help with weight management.
#
# 2) **Blueberries: 9/10**
#    - Packed with antioxidants, vitamins (like vitamin K and C), and fiber. They also have a low calorie count and are heart-healthy.
#
# 3) **Spinach: 8/10**
#    - Rich in vitamins A, C, and K, as well as minerals like iron and calcium. It is low in calories and high in antioxidants.
#
# 4) **Salmon: 8/10**
#    - High in omega-3 fatty acids, high-quality protein, and essential vitamins (like vitamin D). It is heart-healthy and supports brain function.
#
# 5) **Sweet Potatoes: 7/10**
#    - High in fiber, vitamins (especially vitamin A), and antioxidants. They are also relatively low in calories.
#
# 6) **Oats: 7/10**
#    - High in fiber, particularly beta-glucan, which can help lower cholesterol levels. They provide sustained energy and are heart-healthy.
#
# 7) **Almonds: 6/10**
#    - High in healthy fats, protein, fiber, and various vitamins and minerals. They are good for heart health and can aid in weight management.
#
# 8) **Yogurt: 6/10**
#    - High in protein, calcium, and probiotics. It is beneficial for gut health but can vary in sugar content depending on the type.
#
# 9) **White Bread: 3/10**
#    - Low in fiber and nutrients compared to whole grain bread. It is high in refined carbs and can cause rapid spikes in blood sugar.
#
# 10) **Candy: 1/10**
#     - High in sugar and empty calories with little to no nutritional value. It can contribute to weight gain and other health issues if consumed in excess.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_b96696552efd45f9b4748680bbf0f546

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?", session=session
)
print(result.final_output)
# Out:
# Sure, here's a comparison of the healthiness of bananas and lollipops:
#
# 1) Bananas: 9/10 - High in potassium, fiber, and various vitamins and minerals. They are a good source of energy and are low in fat and sodium.
#
# 2) Lollipops: 1/10 - High in sugar with little to no nutritional value. They can contribute to tooth decay and provide empty calories without beneficial nutrients.
#
# So, bananas are much healthier than lollipops.

# %%
with trace("Compare with Memory") as t:
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison", session=session
    )

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: Certainly, here's the comparison including apples:
#
# 1) Bananas: 9/10 - High in potassium, fiber, and various vitamins and minerals. They are a good source of energy and are low in fat and sodium.
#
# 2) Apples: 8/10 - High in fiber, vitamin C, and various antioxidants. They are also good for heart health and can help with digestion.
#
# 3) Lollipops: 1/10 - High in sugar with little to no nutritional value. They can contribute to tooth decay and provide empty calories without beneficial nutrients.
#
# So, bananas are the healthiest, followed by apples, with lollipops being the least healthy.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_137c5a75cff2455d824499b818d027bc
